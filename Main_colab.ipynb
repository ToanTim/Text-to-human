# %% [markdown]
# ## **Text generator**

# %%
# !pip install cohere
import cohere
co = cohere.Client("voUEw0C1SJJIugnJ55Ou8VJCqGvucJVEZtcffFhu")
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#   Created wheel for cohere: filename=cohere-2.8.0-cp37-cp37m-linux_x86_64.whl size=10956 sha256=f77c72e7bde47c44fdd7ac197b1272e4afb2ba58ef9c7eb4c53ec9d7a9a1cd97
#   Stored in directory: /root/.cache/pip/wheels/85/bd/8e/65048fd92114861be1984d02d48bf68b8f2475185178600024
# Successfully built cohere
# ...

# %%
from cohere.classify import Example


examples=[
    #data scientist definition
    Example("data scientist", "Data scientists are a new breed of analytical data expert who have the technical skills to solve complex problems – and the curiosity to explore what problems need to be solved."),
    Example("What is the data scientist", "Data scientists are a new breed of analytical data expert who have the technical skills to solve complex problems – and the curiosity to explore what problems need to be solved."),
    #
    Example("What does data scientist do", "Data scientists examine which questions need answering and where to find the related data. They have business acumen and analytical skills as well as the ability to mine, clean, and present data. Businesses use data scientists to source, manage, and analyze large amounts of unstructured data."),
    Example("What does it mean to be a data scientist", "Data scientists examine which questions need answering and where to find the related data. They have business acumen and analytical skills as well as the ability to mine, clean, and present data. Businesses use data scientists to source, manage, and analyze large amounts of unstructured data."),
    Example("What is the role of data scientist", "Data scientists examine which questions need answering and where to find the related data. They have business acumen and analytical skills as well as the ability to mine, clean, and present data. Businesses use data scientists to source, manage, and analyze large amounts of unstructured data."),
    #
    Example("data scientist skills", "data scientist need to have statistical analysis and computin,machine learning,Deep Learning,Processing large data sets,Data Visualization, Data Wrangling,Mathematics and Programming skill"),
    Example("what do I need to be data scientist", "data scientist need to have statistical analysis and computin,machine learning,Deep Learning,Processing large data sets,Data Visualization, Data Wrangling,Mathematics and Programming skill"),
    
    
    #data analyst definition
    Example("data analyst", "A data analyst is a person whose job is to gather and interpret data in order to solve a specific problem"),
    Example("What is the data analyst", "A data analyst is a person whose job is to gather and interpret data in order to solve a specific problem"),
    #
    Example("What does data analyst do", "A data analyst reviews data to identify key insights into a business's customers and ways the data can be used to solve problems. They also communicate this information to company leadership and other stakeholders."),
    Example("What does it mean to be a data analyst", "A data analyst reviews data to identify key insights into a business's customers and ways the data can be used to solve problems. They also communicate this information to company leadership and other stakeholders."),
    Example("What is the role of data analyst", "A data analyst reviews data to identify key insights into a business's customers and ways the data can be used to solve problems. They also communicate this information to company leadership and other stakeholders."),
    #
    Example("data analyst skills", "data analyst need to have Data cleaning and preparation, Data analysis and exploration, Statistical knowledge, Creating data visualizations, Creating dashboards and reports, Writing and communication"),
    Example("what do I need to be data analyst", "data analyst need to have Data cleaning and preparation, Data analysis and exploration, Statistical knowledge, Creating data visualizations, Creating dashboards and reports, Writing and communication"),


    #software engineer definition
    Example("software engineer", "A software engineer is a person who applies the principles of software engineering to design, develop, maintain, test, and evaluate computer software."),
    Example("What is the software engineer", "A software engineer is a person who applies the principles of software engineering to design, develop, maintain, test, and evaluate computer software."),
    #
    Example("What does software engineer do", "Software engineers design and create computer systems and applications to solve real-world problems. Software engineers, sometimes called software developers, create software for computers and applications"),
    Example("What does it mean to be a software engineer", "Software engineers design and create computer systems and applications to solve real-world problems. Software engineers, sometimes called software developers, create software for computers and applications"),
    Example("What is the role of software engineer", "Software engineers design and create computer systems and applications to solve real-world problems. Software engineers, sometimes called software developers, create software for computers and applications"),
    #
    Example("software engineer skills", "software engineer need to have Computer Programming and Coding, Software Development,Object-Oriented Design (OOD), Software Testing and Debugging,Written and Verbal Communication,Teamwork"),
    Example("what do I need to be software engineer", "software engineer need to have Computer Programming and Coding, Software Development,Object-Oriented Design (OOD), Software Testing and Debugging,Written and Verbal Communication,Teamwork"),

    #Computer Network Architects definition
    Example("Computer Network Architects", "Computer network architects design and build data communication networks, including local area networks (LANs), wide area networks (WANs), and Intranets"),
    Example("What is the Computer Network Architects", "Computer network architects design and build data communication networks, including local area networks (LANs), wide area networks (WANs), and Intranets"),
    #
    Example("What does Computer Network Architects do", "Computer network architects design and build data communication networks, including local area networks (LANs), wide area networks (WANs), and Intranets"),
    Example("What does it mean to be a Computer Network Architects", "Computer network architects design and build data communication networks, including local area networks (LANs), wide area networks (WANs), and Intranets"),
    Example("What is the role of Computer Network Architects", "Computer network architects design and build data communication networks, including local area networks (LANs), wide area networks (WANs), and Intranets"),
    #
    Example("Computer Network Architects skills", "Computer Network Architects need to have Analytical skills, Detail oriented,Interpersonal skills, Leadership skills, Organizational skills"),
    Example("what do I need to be Computer Network Architects", "Computer Network Architects need to have Analytical skills, Detail oriented,Interpersonal skills, Leadership skills, Organizational skills"),


    #Information Security Analysts definition
    Example("Information Security Analysts", "An information security analyst takes measures to protect a company's sensitive and mission-critical data, staying one step ahead of cyber attackers."),
    Example("What is the Information Security Analysts", "An information security analyst takes measures to protect a company's sensitive and mission-critical data, staying one step ahead of cyber attackers."),
    #
    Example("What does Information Security Analysts do", "Information security analysts install software, such as firewalls, to protect computer networks. Information security analysts plan and carry out security measures to protect an organization's computer networks and systems"),
    Example("What does it mean to be a Information Security Analysts", "Information security analysts install software, such as firewalls, to protect computer networks. Information security analysts plan and carry out security measures to protect an organization's computer networks and systems"),
    Example("What is the role of Information Security Analysts", "Information security analysts install software, such as firewalls, to protect computer networks. Information security analysts plan and carry out security measures to protect an organization's computer networks and systems"),
    #
    Example("Information Security Analysts skills", "Information Security Analysts need to have Information technology and networking,Identifying security threats,Analytical skills,Problem-solving,Communication"),
    Example("what do I need to be Information Security Analysts", "Information Security Analysts need to have Information technology and networking,Identifying security threats,Analytical skills,Problem-solving,Communication"),


    #other strings definition
    Example("i want food", "Sorry i did not understand"),
    Example("i want to break up with my girl", "Sorry i did not understand"),
    #
    Example("fuck you", "Sorry i did not understand"),
    Example("i love you", "Sorry i did not understand"),
    Example("how can i kill someone", "Sorry i did not understand")
]

DS = {0: "A photo of Obeo talking, artwork of ((artwork of ({}) as a hologram in background)), 8k".format("data scientist"),
   60: "A photo of Obeo talking, artwork of ((artwork of ({}) as a hologram in background)), 8k".format("data scientist"),
    120: "A photo of Obeo talking, artwork of ((artwork of ({}) as a hologram in background)), 8k".format("data scientist")
}

DA = {0: "A photo of Obeo talking, artwork of ((artwork of ({}) as a hologram in background)), 8k".format("data analyst"),
   60: "A photo of Obeo talking, artwork of ((artwork of ({}) as a hologram in background)), 8k".format("data analyst"),
    120: "A photo of Obeo talking, artwork of ((artwork of ({}) as a hologram in background)), 8k".format("data analyst")
}  

SE = {0: "A photo of Obeo talking, artwork of ((artwork of ({}) as a hologram in background)), 8k".format("software engineer"),
   60: "A photo of Obeo talking, artwork of ((artwork of ({}) as a hologram in background)), 8k".format("software engineer"),
    120: "A photo of Obeo talking, artwork of ((artwork of ({}) as a hologram in background)), 8k".format("software engineer")
}
CNA = {0: "A photo of Obeo talking, artwork of ((artwork of ({}) as a hologram in background)), 8k".format("Computer Network Architects"),
   60: "A photo of Obeo talking, artwork of ((artwork of ({}) as a hologram in background)), 8k".format("Computer Network Architects"),
    120: "A photo of Obeo talking, artwork of ((artwork of ({}) as a hologram in background)), 8k".format("Computer Network Architects")
}
ISA = {0: "A photo of Obeo talking, artwork of ((artwork of ({}) as a hologram in background)), 8k".format("Information Security Analysts"),
   60: "A photo of Obeo talking, artwork of ((artwork of ({}) as a hologram in background)), 8k".format("Information Security Analysts"),
    120: "A photo of Obeo talking, artwork of ((artwork of ({}) as a hologram in background)), 8k".format("Information Security Analysts")
}

WD = {0: "A photo of Obeo talking, artwork of ((artwork of ({}) as a hologram in background)), 8k".format("web developer"),
   60: "A photo of Obeo talking, artwork of ((artwork of ({}) as a hologram in background)), 8k".format("web developer"),
    120: "A photo of Obeo talking, artwork of ((artwork of ({}) as a hologram in background)), 8k".format("web developer")
}


examples2=[
    #data scientist definition
    Example("data scientist", str(DS)),
    Example("What is the data scientist", str(DS)),
    #
    Example("What does data scientist do", str(DS)),
    Example("What does it mean to be a data scientist", str(DS)),
    Example("What is the role of data scientist", str(DS)),
    #
    Example("data scientist skills", str(DS)),
    Example("what do I need to be data scientist", str(DS)),
    

    #data analyst definition
    Example("data analyst", str(DA)),
    Example("What is the data analyst", str(DA)),
    #
    Example("What does data analyst do", str(DA)),
    Example("What does it mean to be a data analyst", str(DA)),
    Example("What is the role of data analyst", str(DA)),
    #
    Example("data analyst skills", str(DA)),
    Example("what do I need to be data analyst", str(DA)),


    #software engineer definition
    Example("software engineer", str(SE)),
    Example("What is the software engineer", str(SE)),
    #
    Example("What does software engineer do", str(SE)),
    Example("What does it mean to be a software engineer", str(SE)),
    Example("What is the role of software engineer", str(SE)),
    #
    Example("software engineer skills", str(SE)),
    Example("what do I need to be software engineer", str(SE)),

    #Computer Network Architects definition
    Example("Computer Network Architects", str(CNA)),
    Example("What is the Computer Network Architects", str(CNA)),
    #
    Example("What does Computer Network Architects do", str(CNA)),
    Example("What does it mean to be a Computer Network Architects", str(CNA)),
    Example("What is the role of Computer Network Architects", str(CNA)),
    #
    Example("Computer Network Architects skills", str(CNA)),
    Example("what do I need to be Computer Network Architects", str(CNA)),


    #Information Security Analysts definition
    Example("Information Security Analysts", str(ISA)),
    Example("What is the Information Security Analysts", str(ISA)),
    #
    Example("What does Information Security Analysts do", str(ISA)),
    Example("What does it mean to be a Information Security Analysts", str(ISA)),
    Example("What is the role of Information Security Analysts", str(ISA)),
    #
    Example("Information Security Analysts skills", str(ISA)),
    Example("what do I need to be Information Security Analysts", str(ISA)),



    #web developer definition
    Example("web developer", str(WD)),
    Example("What is the web developer", str(WD)),
    #
    Example("What does web developer do", str(WD)),
    Example("What does it mean to be a web developer", str(WD)),
    Example("What is the role of web developer", str(WD)),
    #
    Example("web developer skills", str(WD)),
    Example("what do I need to be web developer", str(WD))
]

# %% [markdown]
# ##### User input

# %%
while True:
  text= input("Hello, how can i help you?\n")
  inputs=[
        text
        ]
  response_audio = co.classify(  
      model='large',  
      inputs=inputs,  
      examples=examples)

  #''' response_prompt = co.classify(  
  #    model='medium',  
  #    inputs=inputs,  
  #    examples=examples2) '''

  AI_response = str(response_audio.classifications[0]).split('"')[1]
  if AI_response != "Sorry i did not understand":
    
    break
  else:
    print(AI_response)
AI_response
# Out:
# Hello, how can i help you?
# i want breakfast
# Sorry i did not understand
# Hello, how can i help you?
# i want understand what  is a data science
# 'Data scientists examine which questions need answering and where to find the related data. They have business acumen and analytical skills as well as the ability to mine, clean, and present data. Businesses use data scientists to source, manage, and analyze large amounts of unstructured data.'

# %%
response_video = co.classify(  
    model='large',  
    inputs=inputs,  
    examples=examples2)

''' response_prompt = co.classify(  
    model='medium',  
    inputs=inputs,  
    examples=examples2) '''

animation_prompts = eval(str(response_video.classifications[0]).split('"')[1])
animation_prompts
# Out:
# {0: 'A photo of Obeo talking, artwork of ((artwork of (data scientist) as a hologram in background)), 8k',
#  60: 'A photo of Obeo talking, artwork of ((artwork of (data scientist) as a hologram in background)), 8k',
#  120: 'A photo of Obeo talking, artwork of ((artwork of (data scientist) as a hologram in background)), 8k'}

# %% [markdown]
# ## **From Text to Audio**

# %%
# %cd /content
# !ls
# Out:
# /content
# sample_data

# %%
# the scipy version packaged with colab is not tolerant of misformated WAV files.
# install the latest version.
# !pip3 install -U scipy
# !pip install pydub
# !git clone https://github.com/jnordberg/tortoise-tts.git
# %cd tortoise-tts
# !pip3 install transformers==4.19.0
# !pip3 install -r requirements.txt
# !python3 setup.py install
# Imports used through the rest of the notebook.
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
# Cloning into 'tortoise-tts'...
# remote: Enumerating objects: 1481, done.
# remote: Total 1481 (delta 0), reused 0 (delta 0), pack-reused 1481
# Receiving objects: 100% (1481/1481), 53.58 MiB | 31.97 MiB/s, done.
# Resolving deltas: 100% (590/590), done.
# /content/tortoise-tts
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      |████████████████████████████████| 4.2 MB 7.7 MB/s
# ...
#      |████████████████████████████████| 182 kB 51.0 MB/s
# ...
#      |████████████████████████████████| 6.6 MB 21.5 MB/s
# ...
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      |████████████████████████████████| 41 kB 518 kB/s
# ...
#      |████████████████████████████████| 235 kB 13.3 MB/s
# ...

# %%
import torch
import torchaudio
import torch.nn as nn
import torch.nn.functional as F

import IPython

from tortoise.api import TextToSpeech
from tortoise.utils.audio import load_audio, load_voice, load_voices

# This will download all the models used by Tortoise from the HuggingFace hub.
tts = TextToSpeech()
from pydub import AudioSegment
# Out:
# Downloading:   0%|          | 0.00/2.06k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/1.18G [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/159 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/1.57k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/181 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/85.0 [00:00<?, ?B/s]
# ...
# Done.
# ...
# Done.
# ...
# Done.
# ...
# Done.
# ...
# Done.
# ...
# Done.
# ...
# Done.
# ...
# Done.

# %%
def text_to_speech(text = "This is a text  to voice DEMO provided by factory of the sol", preset= "fast", voice = 'geralt', output = '/content/tortoise-tts/tortoise/voices/file3.mp3'):
  # Load it and send it through Tortoise.
  voice_samples, conditioning_latents = load_voice(voice)
  gen = tts.tts_with_preset(text, voice_samples=voice_samples, conditioning_latents=conditioning_latents, 
                            preset=preset)
  torchaudio.save('generated.wav', gen.squeeze(0).cpu(), 24000)
  generated_voice = IPython.display.Audio('generated.wav')
  AudioSegment.from_wav("generated.wav").export(output, format="mp3")
  return(generated_voice)
#daniel, deniro
text_to_speech(voice = 'freeman', text = AI_response)
# Out:
# Generating autoregressive samples..
# 100%|██████████| 6/6 [01:28<00:00, 14.69s/it]
# Computing best candidates using CLVP and CVVP
#   0%|          | 0/6 [00:00<?, ?it/s]/usr/local/lib/python3.7/dist-packages/torch/utils/checkpoint.py:25: UserWarning: None of the inputs have requires_grad=True. Gradients will be None
#   warnings.warn("None of the inputs have requires_grad=True. Gradients will be None")
# 100%|██████████| 6/6 [00:11<00:00,  1.90s/it]
# Transforming autoregressive outputs into audio..
# 100%|██████████| 80/80 [00:53<00:00,  1.49it/s]
#                 <audio  controls="controls" >
#                     <source src="data:audio/x-wav;base64,..." type="audio/x-wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
# %cd /content
# !ls
# Out:
# /content
# sample_data  tortoise-tts

# %%
#@title 1.Upload input_video.mp4 & input_audio.wav files
# %cd sample_data/
# %ls
from google.colab import files
uploaded = files.upload()
# %cd ..
# Out:
# /content/sample_data
# 'Output_video_2 (1).mp4'   Output_video_2.mp4
#      <input type="file" id="files-724d7ca0-a2c1-4952-91b1-bf24a83da881" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-724d7ca0-a2c1-4952-91b1-bf24a83da881">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# ...

# %%
# %cd /content

# %%
#@title <h1>Install Wav2Lip</h1>
#@markdown * Install dependencies
#@markdown * Download models
# !rm -rf /content/sample_data
# !mkdir /content/sample_data

# !git clone https://github.com/zabique/Wav2Lip

#download the pretrained model
# !wget 'https://iiitaphyd-my.sharepoint.com/personal/radrabha_m_research_iiit_ac_in/_layouts/15/download.aspx?share=EdjI7bZlgApMqsVoEUUXpLsBxqXbn5z8VTmoxp55YNDcIA' -O '/content/Wav2Lip/checkpoints/wav2lip_gan.pth'
# !wget 'https://iiitaphyd-my.sharepoint.com/:u:/g/personal/radrabha_m_research_iiit_ac_in/Eb3LEzbfuKlJiR600lQWRxgBIY27JZg80f7V9jtMfbNDaQ?e=TBFBVW' -O '/content/Wav2Lip/checkpoints/wav2lip.pth'
# !pip install https://raw.githubusercontent.com/AwaleSajil/ghc/master/ghc-1.0-py3-none-any.whl

# !pip uninstall tensorflow tensorflow-gpu
# !cd Wav2Lip && pip install -r requirements.txt

#download pretrained model for face detection
# !wget "https://www.adrianbulat.com/downloads/python-fan/s3fd-619a316812.pth" -O "/content/Wav2Lip/face_detection/detection/sfd/s3fd.pth"

# !pip install -q youtube-dl
# !pip install ffmpeg-python
from IPython.display import clear_output 
clear_output()
print("\nDone")
# Out:
# Done

# %%
# %ls

# %% [markdown]
# ## *wave2lip*
# # **Quick guide**
# 1. Create video file input_video.mp4
# 2. Create audio file input_audio.wav
# 3. Both files have to be exact same length
# 4. Target face in the input_video.mp4, must be in ALL videoframes (So no black or blurry frames etc)

# %%
#@title 2.Create Wav2Lip video (using wav2lip_gan.pth) GAN
# !cd Wav2Lip && python inference.py --checkpoint_path checkpoints/wav2lip_gan.pth --face "/content/sample_data/Obeo_3.mp4" --audio "/content/tortoise-tts/generated.wav"
#--pads 10 10 10 10 --resize_factor 1
# Out:
# Using cuda for inference.
# Reading video frames...
# Number of frames available for inference: 420
# (80, 1189)
# Length of mel chunks: 442
#   0% 0/4 [00:00<?, ?it/s]
#   0% 0/27 [00:00<?, ?it/s]
#   4% 1/27 [00:04<01:56,  4.47s/it]
#   7% 2/27 [00:05<00:58,  2.33s/it]
#  11% 3/27 [00:06<00:39,  1.63s/it]
#  15% 4/27 [00:06<00:29,  1.30s/it]
#  19% 5/27 [00:07<00:24,  1.12s/it]
#  22% 6/27 [00:08<00:21,  1.01s/it]
#  26% 7/27 [00:09<00:18,  1.06it/s]
#  30% 8/27 [00:10<00:17,  1.11it/s]
#  33% 9/27 [00:10<00:15,  1.15it/s]
#  37% 10/27 [00:11<00:14,  1.17it/s]
#  41% 11/27 [00:12<00:13,  1.18it/s]
#  44% 12/27 [00:13<00:12,  1.19it/s]
#  48% 13/27 [00:14<00:11,  1.21it/s]
#  52% 14/27 [00:14<00:10,  1.21it/s]
#  56% 15/27 [00:15<00:09,  1.22it/s]
#  59% 16/27 [00:16<00:08,  1.23it/s]
#  63% 17/27 [00:17<00:08,  1.24it/s]
#  67% 18/27 [00:18<00:07,  1.24it/s]
#  70% 19/27 [00:18<00:06,  1.24it/s]
#  74% 20/27 [00:19<00:05,  1.24it/s]
#  78% 21/27 [00:20<00:04,  1.24it/s]
# ...

# %%
#@title 3.Play result video -  50% scaling
from IPython.display import HTML
from base64 import b64encode
mp4 = open('/content/Wav2Lip/results/result_voice.mp4','rb').read()
data_url = "data:video/mp4;base64," + b64encode(mp4).decode()
HTML(f"""
<video width="50%" height="50%" controls>
      <source src="{data_url}" type="video/mp4">
</video>""")
# Out:
# <video width="50%" height="50%" controls>
#       <source src="data:video/mp4;base64,..." type="video/mp4">
# </video>

# %%
#@title 4.Download Result.mp4 to your computer
from google.colab import files
files.download('/content/Wav2Lip/results/result_voice.mp4')

# %% [markdown]
# ---
